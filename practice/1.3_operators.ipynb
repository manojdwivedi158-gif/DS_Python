# %% [markdown]
# # Arithmatic operator
# # Comparison operator
# # Logical operator (AND OR NOT)

# %%
a=15
b=10
add=a+b  #addition
sub=a-b #subtraction
multiplication=a*b
div =a/b  #divide
floor_div=a//b
mod=a%b #modulus
expo=a**b #exponentation

print(add)
print(sub)
print(multiplication)
print(div)
print(floor_div)
print(mod)
print(expo)
# Out:
# 25
# 5
# 150
# 1.5
# 1
# 5
# 576650390625

# %%
add=a+b  #addition
sub=a-b #subtraction
multiplication=a*b
div =a/b  #divide
floor_div=a//b  # it prints only integer value (nearest lower integer) 
mod=a%b #modulus  used to find remainder.
expo=a**b #exponentation  (it means a power b )

# %% [markdown]
# # Comparison Operator
# # these operators are case sensitive

# %%
# equal to ==    
a=5
b=5
result = a==b
print(result)
# Out:
# True

# %%
a=5
b=10
result = a==b
print(result)
# Out:
# False

# %%
name="Manoj"
Name ="Manoj"
result= name==Name
print(result)
# Out:
# True

# %%
name="manoj"
Name ="Manoj"
result= name==Name
result2= name!=Name
print(result)
print(result2)
print(name==Name)
# Out:
# False
# True
# False

# %%
# not equal to 
# greater then
#less then

val1=5
val2=10
print(val1 != val2)
print(val1 > val2)  # 5 is not greater then 10

print(val1 < val2) # 10 is greater then 5

print(val1 >= val2)  #5 is not greater then or equal to 10
print(val1 <= val2)  #5 is less then 10

print(val1 // val2) # 5 divided by 10
print(val2 // val1) # 10 divided by 5
print(val1 ** val2)  # 5 ki power 10
# Out:
# True
# False
# True
# False
# True
# 0
# 2
# 9765625

# %%
a=2
b=5
print(a/b)
print(a//b)
print(a*b)
print(a**b)  # Exponentiation
# Out:
# 0.4
# 0
# 10
# 32

# %% [markdown]
# # Logical Operator
#
#     AND, OR, NOT

# %%
a=True
b=False
result = a and b
print(result)
# Out:
# False

# %%
print(a and b)
print(a or b)
print(not b)
# Out:
# False
# True
# True

# %%
c=True
d=True
print(d and d)
print(c or d)
print(not d)
print(not c)
# Out:
# True
# True
# False
# False

# %%
y=False
z=True
print(not y)
print(not z)
# Out:
# True
# False

# %%
age =int(input("Enter your number:"))
if age<=13:
    print("you are child")

elif age<18:
    print("you are teenage")
elif age==18:
    print("you are an adult")
else:
    print("your are a pro:")
# Out:
# you are teenage

# %%
age>=18
# Out:
# True

# %%
# conditional statement

# in condotional statement you can place one more if, else if, or else condition in another if, else if or else condition to make it conditional statement:

# Check th number is even or odd:

num=int(input("enter your nuber"))

if num>0:
    print("The number is positive")

    if(num%2==0):
        print("the number is even")
    else:
        print("the number is odd")

else:
    print("the number is negative")
# Out:
# the number is negative

# %%
## Leap year:

year  =  int(input("enter the year:"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print("notr year is leap year..")
        else:
            print("not leap year")
    else:
        print("leap year")       
else:
    print("not a leap year")
# Out:
# leap year

# %%
str="MANOJ DWIVEDI"
for i in str:
    print(i)
# Out:
# M
# A
# N
# O
# J
#
# D
# W
# I
# V
# E
# D
# I
