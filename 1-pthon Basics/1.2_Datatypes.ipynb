# %% [markdown]
# ##  Basic Data Types-
#   integer
#   float
#   string
#   boolean
#
# ## Advanced Data Types
#   lists
#   Tuples
#   sets
#   dictionaries

# %%
# Integer Example
age=25
print(type(age))
# Out:
# <class 'int'>

# %%
# floating point datatype
height=5.5
print(height)
print(type(height))
# Out:
# 5.5
# <class 'float'>
