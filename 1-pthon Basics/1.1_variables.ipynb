# %%
## Basic Sntax in python
## Case Sensitivity Python is case sensitive 

name="Manoj"
Name="Dwivedi"

print(name)
print(Name)
# Out:
# Manoj
# Dwivedi

# %%
print("hello")
# Out:
# hello

# %%
##  Indentation 
## Python uses indentation to  define blocks of code  spaces ot tab used where these are required


age=25

if (age>20):
    print(age)
print(20)
# Out:
# 25
# 20

# %%
 ##Line continuation
##  Backslash  ( \ ) is used for line continuation

total=2+3+4+5+69+ \
 5+8+9
print(total)
# Out:
# 105

# %%
# Multiple line statement
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
type(Name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
print(type(Name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Type inference
var="manoj"
print(type(var))
var=2
print(type(var))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Name error
# a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
# Example of indentation
if True:
    print("it is true")
    if False:
        print("if false it run")
    print ("it should run")
    print("it will run")
# Out:
# it is true
# it should run
# it will run

# %%
if True:
    print("it is true")
    if False:
        print("if false it run")
        print ("it should run")
    print("it will run")
# Out:
# it is true
# it will run

# %%
# Declearing and assigning variable

name="manoj dwivedi"
age=24
is_student=True

# printing the variables

print(name)
print(age)
print(is_student)
# Out:
# manoj dwivedi
# 24
# True

# %%
# Python is dynamically typed language  ,means... type of variable is determined at runtime

# type conversion
age=24
print(type(age))
age=str(age)
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Input

age=int(input("what is your age"))
print(age)
# Out:
# 24

# %%
print("hello")
# Out:
# hello
